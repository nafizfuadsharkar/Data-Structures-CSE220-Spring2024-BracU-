# %%
class BTNode:
  def __init__(self, elem):
    self.elem = elem
    self.right = None
    self.left = None

# %%
def inorder(root):
  if root == None:
    return

  inorder(root.left)
  print(root.elem, end = ' ')
  inorder(root.right)

# %%
def tree_construction(arr, i = 1):
  if i>=len(arr) or arr[i] == None:
    return None
  p = BTNode(arr[i])
  p.left = tree_construction(arr, 2*i)
  p.right = tree_construction(arr, 2*i+1)
  return p


root2 = tree_construction([None, 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', None, None, None, 'I', 'J', None, 'k'])
inorder(root2)
# Out:
# H D B E A I F J C G k

# %% [markdown]
# Task 1

# %%
def convert_mirror(root):
  #To Do
  if root == None:
    return
  nw_root=BTNode(root.elem)
  right=convert_mirror(root.right)
  nw_root.left = right
  left=convert_mirror(root.left)
  nw_root.right = left
  return nw_root


#DRIVER CODE
root = BTNode(10)
n1 = BTNode(20)
n2 = BTNode(30)
n3 = BTNode(40)
n4 = BTNode(60)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  40 20 60 10 30
print()

root2 = convert_mirror(root)
print('Mirrored Tree Inorder Traversal: ', end = ' ')
inorder(root2) #Mirrored Tree Inorder Traversal:  30 10 60 20 40
# Out:
# Given Tree Inorder Traversal:  40 20 60 10 30
# Mirrored Tree Inorder Traversal:  30 10 60 20 40

# %% [markdown]
# Task 2

# %%
def smallest_level(root):
  #To Do
  if root is None:
    return []
  rslt = []
  queue = [root]
  while queue:
    current_level_size = len(queue)
    min_value = float('inf')
    for _ in range(current_level_size):
      node = queue.pop(0)
      min_value = min(min_value, node.elem)
      if node.left:
        queue.append(node.left)
      if node.right:
        queue.append(node.right)
    rslt.append(min_value)

  strng = ''
  for i in rslt :
    strng = strng + str(i) + ' '
  return strng


#DRIVER CODE
root = tree_construction([None, 4,9,2,3,-5,None,7])
print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  3 9 5 4 2 7
print()
print('Level Wise Smallest Value: ', end = ' ')
print(smallest_level(root)) #Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}
# Out:
# Given Tree Inorder Traversal:  3 9 -5 4 2 7
# Level Wise Smallest Value:  4 2 -5

# %% [markdown]
# Task 3

# %%
def mximum(x):
  while x.right!=None:
    x=x.right
  return x

def inorder_predecessor(root, x):
  #To Do
  if root==None:
    return None

  pred=None
  while root is not None:
    if x.elem < root.elem:
      root=root.left
    elif x.elem > root.elem:
      pred = root
      root = root.right
    else:
      if root.left is not None:
        pred = mximum(root.left)
      break

  return pred

#DRIVER CODE
root = BTNode(20)
n1 = BTNode(8)
n2 = BTNode(22)
n3 = BTNode(4)
n4 = BTNode(12)
n5 = BTNode(10)
n6 = BTNode(14)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

n4.left = n5
n4.right = n6

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  4 8 10 12 14 20 22
print()

x = root
print(f'Inorder predecessor of node {x.elem}: {inorder_predecessor(root, x).elem}') #Inorder predecessor of node 20: 14
# Out:
# Given Tree Inorder Traversal:  4 8 10 12 14 20 22
# Inorder predecessor of node 20: 14

# %% [markdown]
# Task 4

# %%
def LCA(root, x, y):
  #To Do
  print(root.elem,x.elem,y.elem)
  if root==None:
    return None
  while True:
    if x.elem<root.elem and y.elem<root.elem:
      root=root.left
    elif x.elem>root.elem and y.elem>root.elem:
      root=root.right
    elif x.elem==root.elem and y.elem>root.elem:
      return(x)
    elif y.elem==root.elem and x.elem>root.elem:
      return(y)
    else:
      return root


#DRIVER CODE
#Write by yourself from the given tree
#check all the sample inputs given
root = BTNode(15)
n1 = BTNode(10)
n2 = BTNode(8)
n3 = BTNode(6)
n4 = BTNode(9)
n5 = BTNode(12)
n6 = BTNode(25)
n7 = BTNode(20)
n8 = BTNode(18)
n9 = BTNode(22)
n10 = BTNode(30)


root.left = n1
root.right = n6

n1.left = n2
n1.right = n5

n2.left=n3
n2.roght=n4

n6.left = n7
n6.right = n10

n7.left=n8
n7.right=n9

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root)
print()

x = n3
y = n5
print(f'LCA {x.elem,y.elem}: {LCA(root, x,y).elem}')

x = n7
y = n3
print(f'LCA {x.elem,y.elem}: {LCA(root, x,y).elem}')

x = n8
y = n9
print(f'LCA {x.elem,y.elem}: {LCA(root, x,y).elem}')

x = n6
y = n7
print(f'LCA {x.elem,y.elem}: {LCA(root, x,y).elem}')

x = n1
y = n5
print(f'LCA {x.elem,y.elem}: {LCA(root, x,y).elem}')
# Out:
# Given Tree Inorder Traversal:  6 8 10 12 15 18 20 22 25 30
# 15 6 12
# LCA (6, 12): 10
# 15 20 6
# LCA (20, 6): 15
# 15 18 22
# LCA (18, 22): 20
# 15 25 20
# LCA (25, 20): 25
# 15 10 12
# LCA (10, 12): 10

# %% [markdown]
# Task 5

# %%
def sumTree(root,level=0):
  if root == None:
    return 0
  elif level != 0:
    return (root.elem%level)+sumTree(root.left,level+1)+sumTree(root.right,level+1)
  return root.elem + +sumTree(root.left,level+1) +sumTree(root.right,level+1)

  # To DO
  #you can declare as many helper function with extra parameters as you need .
  #You can not modify the parameters of sumTree or modify any part of the given code.

# %%
#Driver Code
#Input 1
root1 = BTNode(9)
node2 = BTNode(4)
node3 = BTNode(5)
node4 = BTNode(18)
node5 = BTNode(14)
node6 = BTNode(3)
node7 = BTNode(54)
node8 = BTNode(12)
node9 = BTNode(8)
node10 = BTNode(91)
node11 = BTNode(56)

root1.left = node2
root1.right = node3

node2.left = node4

node3.left = node5
node3.right = node6

node4.left = node7
node4.right = node8

node5.left = node9

node8.left = node10
node8.right = node11

print(sumTree(root1)) #This should print 15
# Out:
# 15

# %% [markdown]
# Task 6

# %%
def swap_child(root, level, M):
  #To Do
  if root is None:
    return

  if level < M:
    root.left, root.right = root.right, root.left
  swap_child(root.left, level + 1, M)
  swap_child(root.right, level + 1, M)
  return root


#Driver Code
root=BTNode('A')
#Write other nodes by yourself from the given tree of Doc File
node1 = BTNode('B')
node2 = BTNode('C')
node3 = BTNode('D')
node4 = BTNode('E')
node5 = BTNode('F')
node6 = BTNode('G')
node7 = BTNode('H')
node8 = BTNode('I')
node9 = BTNode('J')

root.left = node1
root.right = node2

node1.left = node3
node1.right = node4


node2.right = node5

node3.left = node6
node3.right = node7

node4.left = node8

node5.left = node9

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root)   #Given Tree Inorder Traversal: G D H B I E A C J F
print()


root2 = swap_child(root, 0, 2)
print('Swapped Tree Inorder Traversal: ', end = ' ')
inorder(root2)  #Swapped Tree Inorder Traversal: J F C A I E B G D H
# Out:
# Given Tree Inorder Traversal:  G D H B I E A C J F
# Swapped Tree Inorder Traversal:  J F C A I E B G D H

# %% [markdown]
# Task 7

# %%
def new_sum(root):
  if root == None:
    return 0
  return root.elem+new_sum(root.left)+new_sum(root.right)


def subtract_summation(root):
  #To Do
  return new_sum(root.left) - new_sum(root.right)


#Driver Code
root=BTNode(71)
#Write other nodes by yourself from the given tree of Doc File
node1 = BTNode(27)
node2 = BTNode(62)
node3 = BTNode(80)
node4 = BTNode(75)
node5 = BTNode(41)
node6 = BTNode(3)
node7 = BTNode(87)
node8 = BTNode(56)
node9 = BTNode(19)
node10 = BTNode(89)

root.left = node1
root.right = node2

node1.left = node3
node1.right = node4

node2.left = node5
node2.right = node6

node3.left = node7
node3.right = node8

node5.left = node9
node5.right = node10

print(subtract_summation(root)) #This should print 111
# Out:
# 111

# %% [markdown]
# Bonus Task

# %%
def level_sum(root):
  if root is None:
    return 0

  left_sum = level_sum(root.left)
  right_sum = level_sum(root.right)

  if root.elem % 2 == 0:
    return left_sum + right_sum + root.elem

  else:
    return left_sum + right_sum - root.elem

#DRIVER CODE
root = BTNode(1)
n2 = BTNode(2)
n3 = BTNode(3)
n4 = BTNode(4)
n5 = BTNode(5)
n6 = BTNode(6)
n7 = BTNode(7)
n8 = BTNode(8)
root.left = n2
root.right = n3

n2.left = n4
n3.left = n5
n3.right = n6

n5.left = n7
n5.right = n8


print(level_sum(root)) #This should print 4
# Out:
# 4
